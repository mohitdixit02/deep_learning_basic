# %% [markdown]
# #### (PoS) Part of Speech Tagging using spacy

# %%
import os
import spacy
from spacy import displacy

# %%
text = """Machine learning is a powerful technology that helps computers learn from data. Deep learning is a subset of machine learning that uses neural networks. Computer vision uses machine learning to analyze images and videos."""
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)
# adding padding in print for better readability
for token in doc:
    print("." * 60)
    print(f"| Text: {token.text:15} | POS: {token.pos_:10} | Tag: {token.tag_:10}")
    print(f"Explanation: {spacy.explain(token.tag_)}")
    print()
# Out:
# ............................................................
# | Text: Machine         | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: learning        | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: is              | POS: AUX        | Tag: VBZ
# Explanation: verb, 3rd person singular present
#
# ............................................................
# | Text: a               | POS: DET        | Tag: DT
# Explanation: determiner
#
# ............................................................
# | Text: powerful        | POS: ADJ        | Tag: JJ
# Explanation: adjective (English), other noun-modifier (Chinese)
#
# ............................................................
# | Text: technology      | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: that            | POS: PRON       | Tag: WDT
# Explanation: wh-determiner
#
# ............................................................
# | Text: helps           | POS: VERB       | Tag: VBZ
# Explanation: verb, 3rd person singular present
#
# ............................................................
# | Text: computers       | POS: NOUN       | Tag: NNS
# Explanation: noun, plural
#
# ............................................................
# | Text: learn           | POS: VERB       | Tag: VB
# Explanation: verb, base form
#
# ............................................................
# | Text: from            | POS: ADP        | Tag: IN
# Explanation: conjunction, subordinating or preposition
#
# ............................................................
# | Text: data            | POS: NOUN       | Tag: NNS
# Explanation: noun, plural
#
# ............................................................
# | Text: .               | POS: PUNCT      | Tag: .
# Explanation: punctuation mark, sentence closer
#
# ............................................................
# | Text: Deep            | POS: ADJ        | Tag: JJ
# Explanation: adjective (English), other noun-modifier (Chinese)
#
# ............................................................
# | Text: learning        | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: is              | POS: AUX        | Tag: VBZ
# Explanation: verb, 3rd person singular present
#
# ............................................................
# | Text: a               | POS: DET        | Tag: DT
# Explanation: determiner
#
# ............................................................
# | Text: subset          | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: of              | POS: ADP        | Tag: IN
# Explanation: conjunction, subordinating or preposition
#
# ............................................................
# | Text: machine         | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: learning        | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: that            | POS: PRON       | Tag: WDT
# Explanation: wh-determiner
#
# ............................................................
# | Text: uses            | POS: VERB       | Tag: VBZ
# Explanation: verb, 3rd person singular present
#
# ............................................................
# | Text: neural          | POS: ADJ        | Tag: JJ
# Explanation: adjective (English), other noun-modifier (Chinese)
#
# ............................................................
# | Text: networks        | POS: NOUN       | Tag: NNS
# Explanation: noun, plural
#
# ............................................................
# | Text: .               | POS: PUNCT      | Tag: .
# Explanation: punctuation mark, sentence closer
#
# ............................................................
# | Text: Computer        | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: vision          | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: uses            | POS: VERB       | Tag: VBZ
# Explanation: verb, 3rd person singular present
#
# ............................................................
# | Text: machine         | POS: NOUN       | Tag: NN
# Explanation: noun, singular or mass
#
# ............................................................
# | Text: learning        | POS: VERB       | Tag: VBG
# Explanation: verb, gerund or present participle
#
# ............................................................
# | Text: to              | POS: PART       | Tag: TO
# Explanation: infinitival "to"
#
# ............................................................
# | Text: analyze         | POS: VERB       | Tag: VB
# Explanation: verb, base form
#
# ............................................................
# | Text: images          | POS: NOUN       | Tag: NNS
# Explanation: noun, plural
#
# ............................................................
# | Text: and             | POS: CCONJ      | Tag: CC
# Explanation: conjunction, coordinating
#
# ............................................................
# | Text: videos          | POS: NOUN       | Tag: NNS
# Explanation: noun, plural
#
# ............................................................
# | Text: .               | POS: PUNCT      | Tag: .
# Explanation: punctuation mark, sentence closer

# %%
# Context based PoS tagging
text2 = "I left the room"
text3 = "Plate is on the left side of the table"

doc2 = nlp(text2)
doc3 = nlp(text3)

# %%
left_w_token1 = doc2[1]
left_w_token2 = doc3[4]
print(f"Text: {left_w_token1.text} | POS: {left_w_token1.pos_} | Tag: {left_w_token1.tag_}, | Explanation: {spacy.explain(left_w_token1.tag_)}")
print(f"Text: {left_w_token2.text} | POS: {left_w_token2.pos_} | Tag: {left_w_token2.tag_}, | Explanation: {spacy.explain(left_w_token2.tag_)}")
# Out:
# Text: left | POS: VERB | Tag: VBD, | Explanation: verb, past tense
# Text: left | POS: ADJ | Tag: JJ, | Explanation: adjective (English), other noun-modifier (Chinese)

# %%
# Visualizing PoS tags using displacy
options = {"distance": 90, "compact": False, "bg": "#000000", "color": "white", "font": "Arial"}
displacy.render(doc, style="dep", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="19de070fa60e4f6fb4c6877b99803de1-0" class="displacy" width="3110" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: white; background: #000000; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">powerful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">helps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">computers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">learn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">data.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Deep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">subset</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">uses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">neural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">networks.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Computer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">vision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">uses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">analyze</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cur
